# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
import pathlib

# %%
# DEFAULT_CITIES = {'New York', 'Chicago'}

DEFAULT_CITIES = {'New York', 'Chicago', 'San Francisco', 'Austin', 'Seattle',
                  'Los Angeles', 'Philadelphia', 'Atlanta', 'Dallas',
                  'Pittsburgh', 'Portland', 'Phoenix', 'Denver', 'Houston',
                  'Miami'}

# %%
def extract_company(result):
    """extract the name of the company"""
    try:
        company = result.find('span', class_='company').get_text().strip()
        return company
    except:
        return None

# %%
def extract_title(result):
    """extract the job title"""
    try:
        title = result.find('a', attrs={'data-tn-element': "jobTitle"}).get('title')
        return title
    except:
        return None

# %%
def extract_star(result):
    """extract a number (width) that is proportional to the number of stars
    shown for the company"""
    try:
        # the 'style' attribute dictates how many stars are filled with color
        star = result.find('span', class_='ratingsContent').get_text()
        # extract only the number
        star = star.replace('""', '').replace('\n', '')
        return star
    except:
        return None

# %%
# Setup basic parameters for the request.get url
url = "http://www.indeed.com/jobs"
params = {'q': 'data scientist', 'radius': '100'}
# params = {'radius': '100'}
max_results = 100

# %%
# Create two df to store scrape value
company_info_df = pd.DataFrame()
company_result_df = pd.DataFrame()

# Loop through default cities list
for city in DEFAULT_CITIES:
    # Loop through the different pages
    for start in range(0, max_results, 10):
        url_params = params.copy()
        # Update the city and page value for each request.get
        url_params.update({'l': city, 'start': start})
        scraped_data = {
                    'company': [],
                    'title': [],
                    'star': []}
        response = requests.get(url, params=url_params)
        soup = BeautifulSoup(response.text, 'lxml')
        results = soup.find_all('div', class_='result')
        
        # Print out url for debugging
        time.sleep(0.05)
        print(response.url)
        print('------------------------------------------------------------------------')
        
        # Loop though the list of scraped data and store into the dict
        for result in results:
            scraped_data['company'].append(extract_company(result))
            scraped_data['title'].append(extract_title(result))
            scraped_data['star'].append(extract_star(result))
        
        # Create df
        result_df = pd.DataFrame(scraped_data)
        # Append the page result into final dataframe
        company_result_df = company_result_df.append(result_df, ignore_index=True)
        
        # Save pages result into separately csv file to debugging purpose 
        company_info_df = pd.DataFrame(scraped_data)
        company_info_df.to_csv('../CSV_files/company_info.csv', mode='a', header=False, index=False)
# Out:
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Philadelphia&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Philadelphia&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Philadelphia&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Philadelphia&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Philadelphia&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Philadelphia&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Philadelphia&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Philadelphia&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Philadelphia&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Philadelphia&start=90
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=San+Francisco&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=San+Francisco&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=San+Francisco&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=San+Francisco&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=San+Francisco&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=San+Francisco&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=San+Francisco&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=San+Francisco&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=San+Francisco&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=San+Francisco&start=90
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Atlanta&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Atlanta&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Atlanta&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Atlanta&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Atlanta&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Atlanta&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Atlanta&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Atlanta&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Atlanta&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Atlanta&start=90
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Portland&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Portland&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Portland&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Portland&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Portland&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Portland&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Portland&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Portland&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Portland&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Portland&start=90
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Phoenix&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Phoenix&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Phoenix&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Phoenix&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Phoenix&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Phoenix&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Phoenix&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Phoenix&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Phoenix&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Phoenix&start=90
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Houston&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Houston&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Houston&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Houston&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Houston&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Houston&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Houston&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Houston&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Houston&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Houston&start=90
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Los+Angeles&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Los+Angeles&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Los+Angeles&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Los+Angeles&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Los+Angeles&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Los+Angeles&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Los+Angeles&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Los+Angeles&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Los+Angeles&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Los+Angeles&start=90
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Seattle&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Seattle&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Seattle&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Seattle&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Seattle&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Seattle&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Seattle&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Seattle&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Seattle&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Seattle&start=90
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Austin&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Austin&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Austin&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Austin&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Austin&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Austin&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Austin&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Austin&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Austin&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Austin&start=90
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=New+York&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=New+York&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=New+York&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=New+York&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=New+York&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=New+York&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=New+York&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=New+York&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=New+York&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=New+York&start=90
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Dallas&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Dallas&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Dallas&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Dallas&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Dallas&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Dallas&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Dallas&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Dallas&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Dallas&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Dallas&start=90
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Pittsburgh&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Pittsburgh&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Pittsburgh&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Pittsburgh&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Pittsburgh&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Pittsburgh&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Pittsburgh&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Pittsburgh&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Pittsburgh&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Pittsburgh&start=90
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Denver&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Denver&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Denver&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Denver&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Denver&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Denver&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Denver&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Denver&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Denver&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Denver&start=90
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Miami&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Miami&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Miami&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Miami&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Miami&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Miami&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Miami&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Miami&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Miami&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Miami&start=90
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Chicago&start=0
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Chicago&start=10
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Chicago&start=20
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Chicago&start=30
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Chicago&start=40
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Chicago&start=50
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Chicago&start=60
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Chicago&start=70
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Chicago&start=80
# ------------------------------------------------------------------------
# https://www.indeed.com/jobs?q=data+scientist&radius=100&l=Chicago&start=90
# ------------------------------------------------------------------------

# %%
# View the scraping result df
company_result_df.head()
# Out:
#                                           location  \
# 0                                             None
# 1                                             None
# 2                                             None
# 3                           Philadelphia, PA 19103
# 4  Philadelphia, PA 19146 (Graduate Hospital area)
#
#                                              company  \
# 0                  The American College of Radiology
# 1                                          Noom Inc.
# 2  North America Service Center for Chinese Stude...
# 3                                            Boxplot
# 4                Children's Hospital of Philadelphia
#
#                                                title  \
# 0                              Clinical Data Manager
# 1            Senior Data Scientist (Remote-friendly)
# 2  房产咨询顾问/Real Estate Consultant/ Real Estate Sal...
# 3                                     Data Scientist
# 4            Data Scientist II - Cell & Gene Therapy
#
#                       salary  star
# 0                       None  None
# 1                       None   4.1
# 2  $80,000 - $150,000 a year  None
# 3             $30,000 a year  None
# 4                       None   4.0

# %%
# Counting the position opening for each company
company_count_df = pd.DataFrame(company_result_df.company.value_counts())
company_count_df = company_count_df.reset_index()
company_count_df.rename(columns = {'index':'company', 'company':'count'}, inplace=True)
company_count_df
# Out:
#                           company  count
# 0    Perceptronics Solutions, Inc    112
# 1              i-Pharm Consulting     73
# 2                            USAA     71
# 3                        TuSimple     43
# 4         Amazon.com Services LLC     41
# ..                            ...    ...
# 815        KeHE Distributors, LLC      1
# 816          Smiths-Digital Forge      1
# 817    TopSpot Internet Marketing      1
# 818                         Viber      1
# 819                       Hyliion      1
#
# [820 rows x 2 columns]

# %%
# Average the rating for each company
company_result_df['star'] = company_result_df['star'].astype(float)
company_rating_df = company_result_df.groupby('company').mean()
company_rating_df = company_rating_df.reset_index()
company_rating_df
# Out:
#                  company  star
# 0          #TeamGoHealth   3.0
# 1                     0x   NaN
# 2          1-800-Flowers   3.7
# 3           132 ENG Inc.   NaN
# 4              9Rooftops   NaN
# ..                   ...   ...
# 815                setld   NaN
# 816          thredUP Inc   2.7
# 817              true[x]   NaN
# 818              viagogo   2.9
# 819  xentity corporation   4.0
#
# [820 rows x 2 columns]

# %%
# Combine position opening and rating into one final df
company_final_df = company_rating_df.merge(company_count_df, on='company')
company_final_df
# Out:
#                  company  star  count
# 0          #TeamGoHealth   3.0      1
# 1                     0x   NaN      1
# 2          1-800-Flowers   3.7      7
# 3           132 ENG Inc.   NaN      2
# 4              9Rooftops   NaN      1
# ..                   ...   ...    ...
# 815                setld   NaN      1
# 816          thredUP Inc   2.7      2
# 817              true[x]   NaN      1
# 818              viagogo   2.9      3
# 819  xentity corporation   4.0      1
#
# [820 rows x 3 columns]

# %%
# Save to csv file
company_final_df.to_csv('../CSV_files/company_rating.csv', mode='w', header=True, index=False)
