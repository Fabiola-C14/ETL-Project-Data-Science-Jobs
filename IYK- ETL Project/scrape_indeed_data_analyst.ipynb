# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
data_scientist = pd.read_csv("scrape_indeed_data_scientist.csv")

# %%
#URL to scrape
url = "http://www.indeed.com/jobs"

# %%
#get response from the URL
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html5lib')

# %%
#Set the intersted cities to search for
DEFAULT_CITIES = {'New York', 'Chicago', 'San Francisco', 'Austin', 'Seattle',
                  'Los Angeles', 'Philadelphia', 'Atlanta', 'Dallas',
                  'Pittsburgh', 'Portland', 'Phoenix', 'Denver', 'Houston',
                  'Miami'}

# %%
params = {'q': 'data analyst', 'radius': '100'}
max_results = 100

# %%
def _location(result):
    try:
        location = result.find('span', class_='location').get_text().strip()
        return location
    except:
        return None

# %%
def _company(result):
    try:
        company = result.find('span', class_='company').get_text().strip()
        return company
    except:
        return None

# %%
def _title(result):
    try:
        title = result.find('a', attrs={'data-tn-element': "jobTitle"}).get(
            'title')
        return title
    except:
        return None

# %%
def _salary(result):
    try:
        company = result.find('span', class_='salaryText').get_text().strip()
        return company
    except:
        return None

# %%
scraped_data = {'location': [],
            'company': [],
            'title': [],
            'salary': []}

for city in DEFAULT_CITIES:
    for start in range(0, max_results, 15):
        url_params = params.copy()
        url_params.update({'l': city, 'start': start})

        response = requests.get(url, params=params)
        soup = BeautifulSoup(response.text, 'lxml')
        results = soup.find_all('div', class_='result')
        
        time.sleep(0.5)
        print(response.url)
        
        for result in results:
            scraped_data['location'].append(_location(result))
            scraped_data['company'].append(_company(result))
            scraped_data['title'].append(_title(result))
            scraped_data['salary'].append(_salary(result))
company_info_df = pd.DataFrame(scraped_data)
# Out:
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100
# https://www.indeed.com/jobs?q=data+analyst&radius=100

# %%
data_analyst = company_info_df.drop_duplicates()

# %%
data_analyst
# Out:
#                                                location  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                   Detroit, MI 48202 (New Center area)
# 7                                     Livonia, MI 48152
# 8                                           Detroit, MI
# 9                       Detroit, MI 48216 (Briggs area)
# 10                                    Newport Beach, CA
# 11    Orlando, FL 32801 (Central Business District a...
# 12                           Bloomfield Hills, MI 48302
# 13                                          Detroit, MI
# 14                                         Bellevue, WA
# 15                    Detroit, MI 48226 (Downtown area)
# 16                                                 None
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 31                                                 None
# 47                                                 None
# 66                                                 None
# 68                                                 None
# 89                                                 None
# 106                                                None
# 141                                                None
# 147                                                None
# 216                                                None
# 220                                                None
# 221                                                None
# 241                                                None
# 259                                                None
# 401                                                None
# 435                                                None
# 548                                                None
# 638                                                None
# 642                                                None
# 657                                                None
# 682                                                None
# 964                                                None
# 1001                                               None
#
#                                             company  \
# 0                         Resolute Management, Inc.
# 1                                              Aldi
# 2                            First Notch Technology
# 3                                              Aldi
# 4                                           Private
# 5                  Integrated Services of Kalamazoo
# 6                                             DPSCD
# 7                                         AccumTech
# 8                                             VROOM
# 9     MICHIGAN CONFERENCE OF TEAMSTERS WELFARE FUND
# 10                                  Lyceum Dynamics
# 11                           Change Everything Inc.
# 12                                    Common Ground
# 13                                   General Motors
# 14                                      Streams Inc
# 15                                    Quicken Loans
# 16                          Michigan Planners, Inc.
# 17           Maschmeyer Concrete Company of Florida
# 18                         JND Legal Administration
# 19                             Starr and Associates
# 20                                     Deacom, Inc.
# 22              Decision Information Resources, Inc
# 23                           Christie Campus Health
# 24                                  Prime MSO, LLC.
# 25                              Qi Venture Partners
# 26                             County of Washington
# 27                       Amida Technology Solutions
# 28                                  Wellview Health
# 31                                    Team Velocity
# 47                           Columbia Marking Tools
# 66                      Asset Protection Unit, Inc.
# 68                         Liberty Mutual Insurance
# 89                                Edge Pharma, LLC.
# 106                              Delta Research Inc
# 141                                  CNS Healthcare
# 147                         Brook Valley Management
# 216                       Auxilior Capital Partners
# 220              Stevens Engineers and Constructors
# 221                                       Dow Jones
# 241            Backer-Springfield (Backer EHP Inc.)
# 259                                          Amfuel
# 401                                  Alliant Energy
# 435                 Paulson Investment Company, LLC
# 548                                   Comerica Bank
# 638             Mid-Delta Durable Medical Equipment
# 642                   Suracy Insurance Agency, Inc.
# 657               InterVarsity Christian Fellowship
# 682                          Collection Experts Inc
# 964                         Bath Community Hospital
# 1001                                           DTSV
#
#                                                title  \
# 0                               Quantitative Analyst
# 1                          Data Analytics Specialist
# 2                              Data Analyst with sql
# 3                        Data Analytics Associate II
# 4                                       Data Analyst
# 5                                       Data Analyst
# 6                  Program Associate I, Data Analyst
# 7                                       Data Analyst
# 8                                       Data Analyst
# 9                     Claims Data Analyst Healthcare
# 10                                      Data Analyst
# 11                               Data Analyst Intern
# 12             Data Analyst - Full-Time (Non-Exempt)
# 13    Data Analyst for Enterprise Integration Intern
# 14                                      Data Analyst
# 15                            Data Solutions Analyst
# 16                    Employee Benefits Plan Analyst
# 17                                      Data Analyst
# 18                                      Data Analyst
# 19                                      Data Analyst
# 20                                   Data Specialist
# 22                               Senior Data Analyst
# 23                             Data Research Analyst
# 24                         Jr. Data Analyst (Jr. DA)
# 25                           Research & Data Analyst
# 26                                   Data Analyst II
# 27                                      Data Analyst
# 28                     Business Intelligence Analyst
# 31                            Mid-Level Data Analyst
# 47                       Customer Service/Data Entry
# 66               Overpayment Data Analyst/Programmer
# 68                            Principal Data Analyst
# 89                           QC Microbiology Analyst
# 106                       Tactical Data Link Analyst
# 141                                 Business Analyst
# 147                              Retail Data Analyst
# 216                            Senior Credit Analyst
# 220                         Project Controls Analyst
# 221            Data Engineer, Newsroom Data Products
# 241                                  Network Analyst
# 259                            Cost/Schedule Analyst
# 401      Senior Data Warehouse/Data Modeling Analyst
# 435        Investment Banking Analyst (Life Science)
# 548      Technical Data Analytics Principal Engineer
# 638                              DME Billing Analyst
# 642                              Senior Data Analyst
# 657                             Data Quality Analyst
# 682                            Data Analyst/Helpdesk
# 964                        Revenue Integrity Analyst
# 1001                                    Data Analyst
#
#                           salary
# 0       $50,000 - $60,000 a year
# 1                 $62,000 a year
# 2                    $22 an hour
# 3                 $26.25 an hour
# 4                    $13 an hour
# 5                           None
# 6                 $64.50 an hour
# 7       $55,000 - $85,000 a year
# 8                           None
# 9              $18 - $22 an hour
# 10             $40 - $50 an hour
# 11                          None
# 12                          None
# 13                          None
# 14                          None
# 15                          None
# 16                          None
# 17                          None
# 18      $60,000 - $80,000 a year
# 19     $80,000 - $106,242 a year
# 20      $60,000 - $95,000 a year
# 22     $80,000 - $115,000 a year
# 23             $23 - $28 an hour
# 24      $38,000 - $60,000 a year
# 25      $50,000 - $65,000 a year
# 26                $17.88 an hour
# 27                          None
# 28      $65,000 - $90,000 a year
# 31                          None
# 47             $14 - $15 an hour
# 66     $70,000 - $100,000 a year
# 68    $110,900 - $143,500 a year
# 89                          None
# 106                         None
# 141                         None
# 147     $60,000 - $75,000 a year
# 216     $65,000 - $75,000 a year
# 220                         None
# 221                         None
# 241                         None
# 259               $50,000 a year
# 401                         None
# 435     $40,000 - $90,000 a year
# 548                         None
# 638                         None
# 642                         None
# 657     $43,000 - $58,000 a year
# 682                         None
# 964                         None
# 1001                        None

# %%
company_df.to_csv('scrape_indeed_data_analyst.csv', index=False, encoding='utf8')

# %%
company_final = pd.merge(data_analyst,data_scientist,how="outer")

# %%
company_final.to_csv('scrape_indeed_combined.csv', index=False, encoding='utf8')
